# %% [markdown]
# 26. Take a number and check whether it is positive, negative, or zero. If positive, check whether it is even or odd.
#
# 27. Take a number and check whether it is even or odd. If even, check whether it is divisible by 4.
#
# 28. Take a number and check whether it is positive. If positive, check whether it is greater than 100.
#
# 29. Take three numbers and find the largest using nested `if` statements.
#
# 30. Take three numbers and find the smallest using nested `if` statements.
#
# 31. Take a student's marks and check:
#
# * Pass or fail
# * If passed, check whether the student scored distinction marks.
#
# 32. Take a person's age and check:
#
# * Eligible to vote or not
# * If eligible, check whether the person is 60 or above.
#
# 33. Take a number and check:
#
# * Positive or negative
# * If positive, check whether it is divisible by 5.
#
# 34. Take two numbers and check:
#
# * Which is greater
# * If they are equal, print that they are equal.
#
# 35. Take a number and check:
#
# * Whether it is between 1 and 100
# * If yes, check whether it is even or odd.
#
# 36. Take a year and check whether it is a leap year using nested conditions.
#
# 37. Take three numbers and check whether:
#
# * The first is greater than the second
# * If yes, check whether the first is also greater than the third.
#
# 38. Take a number and check whether it is divisible by 2. If yes, check whether it is also divisible by 3.
#
# 39. Take a student's marks and determine:
#
# * Fail if below 40
# * If passed, check whether marks are below 60 or 60 and above.
#
# 40. Take a number and check:
#
# * If it is positive
# * If positive, check whether it is less than 50
# * If less than 50, check whether it is even.

# %%
num = int(input("Enter a number: "))

if num > 0 or num < 0 or num == 0:
    if num > 0:
      if num % 2 == 0:
          print("The number is even.")
      else:
          print("The number is odd.")
# Out:
# Enter a number: 66
# The number is even.

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
  if num % 4 == 0:
    print("even and divisible by 4")
  else:
    print("even, not divisible by 4")
else:
  print("odd")
# Out:
# Enter a number: 48
# even and divisible by 4

# %%
num = int(input("Enter a number: "))

if num > 0:
  if num > 100:
    print("positive and greater than 100")
  else:
    print("positive, not greater than 100")
else:
  print("not positive")
# Out:
# Enter a number: 23
# positive, not greater than 100

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))

if a > b:
    if a > c:
        largest = a
    else:
        largest = c
else:
    if b > c:
        largest = b
    else:
        largest = c

print("The largest number is:", largest)
# Out:
# Enter first number: 12
# Enter second number: 121
# Enter third number: 22
# The largest number is: 121.0

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))

if a < b:
    if a < c:
        smallest = a
    else:
        smallest = c
else:
    if b < c:
        smallest = b
    else:
        smallest = c

print("The smallest number is:", smallest)
# Out:
# Enter first number: 12
# Enter second number: 12
# Enter third number: 11
# The smallest number is: 11.0

# %%
marks = int(input("enter the marks: "))

if marks >= 35:
  print("pass")
  if marks > 80:
    print("distinction")
  else:
    print("not distinction")
else:
  print("fail")
# Out:
# enter the marks: 56
# pass
# not distinction

# %%
age = int(input("enter the age: "))

if age >= 18:
  print("eligible to vote")
  if age >= 60:
    print("above or equal to 60")
  else:
    print("not above 60")
else:
  print("no right to vote")
# Out:
# enter the age: 29
# eligible to vote
# not above 60

# %%
num = int(input("Enter a number: "))

if num >= 0:
  if num == 0:
    print("you can divide with 0")
  else:
    if num % 5 == 0:
      print("positive and divisible by 5")
    else:
      print("positive, not divisible by 5")
else:
  print("not positive")
# Out:
# Enter a number: 50
# positive and divisible by 5

# %%
num_1 = int(input("Enter a number_1: "))
num_2 = int(input("Enter a number_2: "))

if num_1 == num_2:
  print("equal")
else:
  if num_1 > num_2:
    print("num_1 is greater")
  else:
    print("num_2 is greater")
# Out:
# Enter a number_1: -3
# Enter a number_2: -9
# num_1 is greater

# %%
num = int(input("Enter a number: "))

if num > 1 and num < 100:
  if num % 2 == 0:
    print("even and b/w 1 and 100")
  else:
    print("odd")
else:
  print("not in b/w 1 to 100")
# Out:
# Enter a number: 98
# even and b/w 1 and 100

# %%
year = int(input("Enter a year: "))

if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
  print("leap year")
else:
  print("not a leap year")
# Out:
# Enter a year: 2020
# leap year

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))

if a > b:
    if a > c:
        largest = a
    else:
        largest = c
else:
    if b > c:
        largest = b
    else:
        largest = c

print("The largest number is:", largest)
# Out:
# Enter first number: 12
# Enter second number: 11
# Enter third number: 10
# The largest number is: 12.0

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
  if num % 3 == 0:
    print("divisible by 2 and 3")
  else:
    print("divisible by 2, not divisible by 3")
else:
  print("not divisible by 2")
# Out:
# Enter a number: 23
# not divisible by 2

# %%
marks = int(input("enter the marks: "))

if marks < 40:
  print("fail")

else:
  if marks > 60:
    print("above 60")
  elif marks == 60:
    print("equal to 60")
  else:
    print("below 60")
# Out:
# enter the marks: 35
# fail

# %%
num = int(input("Enter a number: "))

if num > 0:
  if num < 50:
    if num % 2 == 0:
      print("+ve,< 50 , even")
    else:
      print("+ve,< 50 , odd")
  else:
    print("+ve, > 50")
else:
  print("-ve")
# Out:
# Enter a number: 12
# +ve,< 50 , even
